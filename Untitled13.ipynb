# %% [markdown]
# <a href="https://colab.research.google.com/github/veritaem/energystocks/blob/master/Untitled13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #prelim

# %%
#imports

import numpy as np
import itertools
import dask.dataframe as dd
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#grab files for years 2019, 2018, and 2008
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f906920_2001.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f906920_2002.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f906920_2003.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f906920_2004.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f906920_2005.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f906920_2006.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f906920_2007.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2008.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2009.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2010.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2011.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2012.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2013.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2014.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2015.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2016.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2017.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2018.zip?raw=true
# !wget https://github.com/veritaem/energystocks/blob/master/by_decades/f923_2019.zip?raw=true
# Out:
# --2019-04-23 20:22:04--  https://github.com/veritaem/energystocks/blob/master/by_decades/f906920_2001.zip?raw=true
# Resolving github.com (github.com)... 192.30.253.113, 192.30.253.112
# Connecting to github.com (github.com)|192.30.253.113|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://github.com/veritaem/energystocks/raw/master/by_decades/f906920_2001.zip [following]
# --2019-04-23 20:22:04--  https://github.com/veritaem/energystocks/raw/master/by_decades/f906920_2001.zip
# Reusing existing connection to github.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/veritaem/energystocks/master/by_decades/f906920_2001.zip [following]
# --2019-04-23 20:22:04--  https://raw.githubusercontent.com/veritaem/energystocks/master/by_decades/f906920_2001.zip
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# ...

# %%
#unzip recieved 

# !unzip f906920_2001.zip?raw=true
# !unzip f906920_2002.zip?raw=true
# !unzip f906920_2003.zip?raw=true
# !unzip f906920_2004.zip?raw=true
# !unzip f906920_2005.zip?raw=true
# !unzip f906920_2006.zip?raw=true
# !unzip f906920_2007.zip?raw=true
# !unzip f923_2008.zip?raw=true
# !unzip f923_2009.zip?raw=true
# !unzip f923_2010.zip?raw=true
# !unzip f923_2011.zip?raw=true
# !unzip f923_2012.zip?raw=true
# !unzip f923_2013.zip?raw=true
# !unzip f923_2014.zip?raw=true
# !unzip f923_2015.zip?raw=true
# !unzip f923_2016.zip?raw=true
# !unzip f923_2017.zip?raw=true
# !unzip f923_2018.zip?raw=true
# !unzip f923_2019.zip?raw=true
# Out:
# Archive:  f906920_2001.zip?raw=true
# replace f906920y2001.xls? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: f906920y2001.xls
# Archive:  f906920_2002.zip?raw=true
# replace f906920y2002.xls? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: f906920y2002.xls
# Archive:  f906920_2003.zip?raw=true
# replace f906920_2003.xls? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: f906920_2003.xls
# Archive:  f906920_2004.zip?raw=true
# replace 2004 Nonutility Source and Disposition.xls? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: 2004 Nonutility Source and Disposition.xls
#   inflating: f906920_2004.xls
# Archive:  f906920_2005.zip?raw=true
# replace 2005 Nonutility Source and Disposition.xls? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
#   inflating: 2005 Nonutility Source and Disposition.xls
#   inflating: f906920_2005.xls
# Archive:  f906920_2006.zip?raw=true
# replace 2006 Nonutility Source and Disposition.xls? [y]es, [n]o, [A]ll, [N]one, [r]ename: A
# ...

# %%
#check where im at

# !ls
# Out:
# '2004 Nonutility Source and Disposition.xls'
# '2005 Nonutility Source and Disposition.xls'
# '2006 Nonutility Source and Disposition.xls'
# '2007 Nonutility Source and Disposition.xls'
# '2008 Nonutility Source and Disposition Final version.xlsm'
# '2009 Nonutility Source and Disposition.xls'
# '2010 Nonutility Source and Disposition.xls'
#  eia923December2008.xls
#  EIA923_Schedule_8_Annual_Envir_Infor_2017_Final.xlsx
#  EIA923_Schedule_8_Annual_Environmental_Information_2012_Final_Revision.xlsx
#  EIA923_Schedule_8_Annual_Environmental_Information_2014_Final_Revision.xlsx
#  EIA923_Schedule_8_Annual_Environmental_Information_2015_Final_Revision.xlsx
#  EIA923_Schedule_8_Annual_Environmental_Information_2016_Final_Revision.xlsx
#  EIA923_Schedule_8_PartsA-D_EnvData_2013_Final_Revision.xlsx
#  EIA923_Schedule_8_PartsA-F_EnvData_2011_Final_Revision.xlsx
#  EIA923_Schedules_2_3_4_5_2011_Final_Revision.xlsx
#  EIA923_Schedules_2_3_4_5_2013_Final_Revision.xlsx
# ...

# %%
#read in the excel files(they have multiple sheets) and get out ones i need

xls = pd.ExcelFile('EIA923_Schedules_2_3_4_5_M_01_2019_26MAR2019.xlsx')
xls1 = pd.ExcelFile('EIA923_Schedules_2_3_4_5_M_12_2018_22FEB2019.xlsx')
xls2 = pd.ExcelFile('eia923December2008.xls')
xls3 = pd.ExcelFile('f906920y2001.xls')
xls4 = pd.ExcelFile('f906920y2002.xls')
xls5 = pd.ExcelFile('f906920_2007.xls')
xls6 = pd.ExcelFile('f906920_2006.xls')
xls7 = pd.ExcelFile('f906920_2005.xls')
xls8 = pd.ExcelFile('f906920_2004.xls')
xls9 = pd.ExcelFile('f906920_2003.xls')
xls10 = pd.ExcelFile('EIA923 SCHEDULES 2_3_4_5 Final 2010.xls')
xls11 = pd.ExcelFile('EIA923 SCHEDULES 2_3_4_5 M Final 2009 REVISED 05252011.XLS')
xls12 = pd.ExcelFile('EIA923_Schedules_2_3_4_5_M_12_2012_Final_Revision.xlsx')
xls14 = pd.ExcelFile('EIA923_Schedules_2_3_4_5_2013_Final_Revision.xlsx')
xls15 = pd.ExcelFile('EIA923_Schedules_2_3_4_5_M_12_2014_Final_Revision.xlsx')
xls16 = pd.ExcelFile('EIA923_Schedules_2_3_4_5_M_12_2015_Final_Revision.xlsx')
xls17 = pd.ExcelFile('EIA923_Schedules_2_3_4_5_M_12_2016_Final_Revision.xlsx')
xls18 = pd.ExcelFile('EIA923_Schedules_2_3_4_5_M_12_2017_Final_Revision.xlsx')
xls19 = pd.ExcelFile('EIA923_Schedules_2_3_4_5_2011_Final_Revision.xlsx')

# %%
df2019 = pd.read_excel(xls, 'Page 2 Oil Stocks Data', skiprows =5)
df2018 = pd.read_excel(xls1, 'Page 2 Oil Stocks Data', skiprows =5)
df2008 = pd.read_excel(xls2, 'Page 2 Oil Stocks Data', skiprows =5)
df2001 = pd.read_excel(xls3, 'Page 2 Oil Stocks Data', skiprows =5)
df2002 = pd.read_excel(xls4, 'Page 2 Oil Stocks Data', skiprows =5)
df2003 = pd.read_excel(xls9, 'Page 2 Oil Stocks Data', skiprows =5)
df2004 = pd.read_excel(xls8, 'Page 2 Oil Stocks Data', skiprows =5)
df2005 = pd.read_excel(xls7, 'Page 2 Oil Stocks Data', skiprows =5)
df2006 = pd.read_excel(xls6, 'Page 2 Oil Stocks Data', skiprows =5)
df2007 = pd.read_excel(xls5, 'Page 2 Oil Stocks Data', skiprows =5)
df2009 = pd.read_excel(xls11, 'Page 2 Oil Stocks Data', skiprows =5)
df2010 = pd.read_excel(xls10, 'Page 2 Oil Stocks Data', skiprows =5)
df2011 = pd.read_excel(xls19, 'Page 2 Oil Stocks Data', skiprows =5)
df2012 = pd.read_excel(xls12, 'Page 2 Oil Stocks Data', skiprows =5)
df2013 = pd.read_excel(xls14, 'Page 2 Oil Stocks Data', skiprows =5)
df2014 = pd.read_excel(xls15, 'Page 2 Oil Stocks Data', skiprows =5)
df2015 = pd.read_excel(xls16, 'Page 2 Oil Stocks Data', skiprows =5)
df2016 = pd.read_excel(xls17, 'Page 2 Oil Stocks Data', skiprows =5)
df2017 = pd.read_excel(xls18, 'Page 2 Oil Stocks Data', skiprows =5)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.6/dist-packages/xlrd/book.py in sheet_by_name(self, sheet_name)
#     469         try:
# --> 470             sheetx = self._sheet_names.index(sheet_name)
#     471         except ValueError:
#
# ValueError: 'Page 2 Oil Stocks Data' is not in list
#
# During handling of the above exception, another exception occurred:
#
# XLRDError                                 Traceback (most recent call last)
# <ipython-input-16-5b070eeac3ce> in <module>()
#       2 df2018 = pd.read_excel(xls1, 'Page 2 Oil Stocks Data', skiprows =5)
#       3 df2008 = pd.read_excel(xls2, 'Page 2 Oil Stocks Data', skiprows =5)
# ----> 4 df2001 = pd.read_excel(xls3, 'Page 2 Oil Stocks Data', skiprows =5)
#       5 df2002 = pd.read_excel(xls4, 'Page 2 Oil Stocks Data', skiprows =5)
# ...

# %%
df = df2001.merge(df2002)
df.head()

# %%
#setting display 

pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)
pd.set_option('display.width', 1000)

# %%
#replacing non-numbers with numbers

'''df2019.replace('.', 0, inplace=True)
df2018.replace('.', 0, inplace=True)
df2008.replace('.', 0, inplace=True)'''

# %%
#making new columns for total barrels per year
'''
df2019['totals'] = df2019['Quantity\nJanuary'] + df2019[
    'Quantity\nFebruary'] + df2019['Quantity\nMarch'] + df2019[
    'Quantity\nApril'] + df2019['Quantity\nMay'] + df2019[
    'Quantity\nJune'] + df2019['Quantity\nJuly'] + df2019[
    'Quantity\nAugust'] + df2019['Quantity\nSeptember'] + df2019[
    'Quantity\nOctober'] + df2019['Quantity\nNovember'] + df2019[
    'Quantity\nDecember']

df2018['totals'] = df2018['Quantity\nJanuary'] + df2018[
    'Quantity\nFebruary'] + df2018['Quantity\nMarch'] + df2018[
    'Quantity\nApril'] + df2018['Quantity\nMay'] + df2018[
    'Quantity\nJune'] + df2018['Quantity\nJuly'] + df2018[
    'Quantity\nAugust'] + df2018['Quantity\nSeptember'] + df2018[
    'Quantity\nOctober'] + df2018['Quantity\nNovember'] + df2018[
    'Quantity\nDecember'] 

df2008['totals'] = df2008['Quantity\nJanuary'] + df2008[
    'Quantity\nFebruary'] + df2008['Quantity\nMarch'] + df2008[
    'Quantity\nApril'] + df2008['Quantity\nMay'] + df2008[
    'Quantity\nJune'] + df2008['Quantity\nJuly'] + df2008[
    'Quantity\nAugust'] + df2008['Quantity\nSeptember'] + df2008[
    'Quantity\nOctober'] + df2008['Quantity\nNovember'] + df2008[
    'Quantity\nDecember'] 
'''

# %%
'''df2019_prod = df2019[df2019['totals'] < 22000]
df2018_prod = df2018[df2018['totals'] < 22000]
df2008_prod = df2008[df2008['totals'] < 22000]'''

# %%
'''print(df2018_prod.shape)
print(df2008_prod.shape)
print(df2019_prod.shape)'''

# %%
'''df2019_p = df2019[~df2019.index.isin(df2019_prod.index)]
print(df2019.shape)
print(df2019_p.shape)
print(df2019.totals.sum())
print(df2019_p.totals.sum())'''

# %%
'''df2018_p = df2018[~df2018.index.isin(df2018_prod.index)]
print(df2018.shape)
print(df2018_p.shape)
print(df2018_p.totals.sum())
print(df2018.totals.sum())'''

# %%
'''df2008_p = df2008[~df2008.index.isin(df2008_prod.index)]
print(df2008.shape)
print(df2008_p.shape)
print(df2008.totals.sum())
print(df2008_p.totals.sum())'''

# %% [markdown]
# #exploratory analysis
